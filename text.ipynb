# %% [markdown]
# [가이드](https://www.youtube.com/watch?v=TvfUjW0SEUI)

# %%
import nltk

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
from nltk.tokenize import sent_tokenize
text = '''Hello Mr, Jones, how are you doing today? The weather is great, and city is awesome.
The sky is bright-blue. you should/t call for meeting today'''
tokenized_text = sent_tokenize(text)
print(tokenized_text)
# Out:
# ['Hello Mr, Jones, how are you doing today?', 'The weather is great, and city is awesome.', 'The sky is bright-blue.', 'you should/t call for meeting today']

# %%
from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(text)
print(tokenized_word)
# Out:
# ['Hello', 'Mr', ',', 'Jones', ',', 'how', 'are', 'you', 'doing', 'today', '?', 'The', 'weather', 'is', 'great', ',', 'and', 'city', 'is', 'awesome', '.', 'The', 'sky', 'is', 'bright-blue', '.', 'you', 'should/t', 'call', 'for', 'meeting', 'today']

# %%
## 빈도 모듈?
from nltk.probability import FreqDist
frequency = FreqDist(tokenized_word)
print(frequency)
# Out:
# <FreqDist with 24 samples and 32 outcomes>

# %%
# 사용된 빈도 오름차순 단어
frequency.most_common
# Out:
# <bound method Counter.most_common of FreqDist({',': 3, 'is': 3, 'you': 2, 'today': 2, 'The': 2, '.': 2, 'Hello': 1, 'Mr': 1, 'Jones': 1, 'how': 1, ...})>

# %%
# 그래프
import matplotlib.pyplot as plt
frequency.plot(30, cumulative=False)
plt.show()

# %%
## 텍스트에서 사용되지 않은 단어도 있음 이걸 처리하기 위한 패키지
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(stop_words)
# Out:
# {'doing', "aren't", 'same', 'couldn', 'ma', 'over', 'didn', 'does', 'what', 'such', 'she', 'whom', 'where', 'my', 'this', 'up', "needn't", 'did', "shan't", "didn't", 'can', 'o', 'some', 'most', 'y', 're', 'is', 'further', 'weren', 'in', 'between', 'with', 'an', 'themselves', 'there', 'aren', 'yours', 'that', "mustn't", 'himself', 'mustn', 'through', 'hers', 'won', 'it', 'should', "it's", 'isn', 'its', 'because', "you've", 'against', 'yourself', 'then', 'having', 'after', 'don', 'each', 'these', 'm', "shouldn't", 'before', 'or', 'how', 'his', 'will', 'both', 'hadn', 'from', 'until', 'me', 'haven', "you'd", 'has', "wouldn't", 'of', 'myself', 'yourselves', 't', 'which', 'i', 'down', 'no', "doesn't", 'had', 'again', 'our', 'ain', 'about', 'ourselves', 'nor', "she's", 'been', 'needn', 'mightn', "haven't", 'during', 'not', 'was', 'and', 'are', 'all', 'above', 'doesn', 'here', "hasn't", 'for', 'd', 'your', 'shouldn', "should've", 'few', "wasn't", 'hasn', 'to', 'do', 'once', 'wasn', 'were', 'being', 'by', 'so', 'off', "don't", 'more', "mightn't", 'while', 've', 'their', 'why', 'shan', 'herself', 'we', "hadn't", 'if', 'you', 'other', 'wouldn', 'they', 'theirs', 'them', 'out', "weren't", "you'll", 'who', 'he', "you're", 'any', 'a', 'am', 'into', 'the', 'ours', 'on', 'just', 'very', 'her', 's', 'only', "couldn't", 'but', "isn't", 'be', 'own', "won't", 'have', 'below', 'as', 'll', 'itself', 'too', 'those', 'under', 'now', 'at', 'than', 'when', "that'll", 'him'}
